# %%
2=2
# Out:
#   File "<ipython-input-4-f987af612b42>", line 1
#     2=2
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# # header
# ## sub header
# ### header-3

# %% [markdown]
# ***
# 1.github
# 2.pyhton
# 3.numpy
# ***

# %% [markdown]
# ***
# 1. git
# 2. hub
# ***

# %% [markdown]
# **git
#  hub**
# *hun*

# %% [markdown]
# - Normal
# - italic
# - Bold

# %% [markdown]
# [aleoo](https://www.google.com)
#
# ![73-737479_butterflies-wallpaper-black-beautiful-butterfly.jpg](attachment:73-737479_butterflies-wallpaper-black-beautiful-butterfly.jpg)
# - ![](https://cdn.statically.io/img/r1.ilikewallpaper.net/iphone-x-wallpapers/download/82936/butterfly-perching-on-leaves-iphone-x-wallpaper-ilikewallpaper_com.jpg)

# %% [markdown]
# ```Highlighting
#       code```
